# %%
# load Python packages
import numpy as np  # for numerical python libraries
import matplotlib.pyplot as plt  # for plotting
import scipy.stats as stats

# %% [markdown]
# Section 5: Asset Price Paths

# %%
# Helper functions: Black-Scholes
def sim_jump_diffusion(X0, T, Ndt, mu, sigma, Nsims = 100, type = "BS", lam = 0, m = 0, delta = 0, p = 0.5, eta = [1, 1]):
    ## Basic parameters
    dt = T / Ndt # create time increment
    time = np.linspace(0, T, Ndt+1) # set the different times as a vector
    X = B = np.zeros((Ndt+1,Nsims)) # initialize matrix
    X[0,:] = X0 # initial value of the process

    ## Jump generation function
    def jump_distn(): return 0 # No jumps
    if type == "Merton":
        # Generate jumps
        def jump_distn():
            # Number of jumps - Poisson process
            U = stats.uniform.rvs(size=Nsims)
            jump = U < (1 - np.exp(-lam * dt))  # Interarrival times exponentially dist
            # Jump size - Normal distribution
            jump_size = np.random.normal(loc=m, scale=delta, size=Nsims) # Jump size normally distributed
            return jump * jump_size

    elif type == "Kou":
        def jump_distn():
            # Number of jumps - Poisson process
            U = stats.uniform.rvs(size=Nsims)
            jump = U < (1 - np.exp(-lam * dt))
            # Jump size - Double exponential
            B = np.random.binomial(n = 1, p = p, size = Nsims) # Bernoulli rv - whether jump is positive or negative
            jump_size = np.zeros(Nsims)
            for i in range(Nsims):
                jump_size[i] = (-1)**(B[i] + 1) * np.random.exponential(1/eta[B[i]]) # Jump size exponentially distributed
            return jump * jump_size


    ## Simulation
    for idx in range(Ndt):
        Z = np.random.randn(Nsims)
        X[idx+1,:] = X[idx,:] * np.exp((mu - sigma**2 / 2) * dt + sigma * np.sqrt(dt) * Z + jump_distn())

    return time, X

# %% [markdown]
# Plots

# %%
## Parameters
X0 = 100
mu = 0.05
sigma = 0.5
T = 1
Ndt = 1000
Nsims = 1000 #10000
# Merton
lam = 5
m = [0.01, 0.05]
delta = [0.05, 0.25]
# Kou
p = [0.5, 0.7]
eta = [[10, 10], [5, 5]]

## Figures - Moderate Parameters
ylim = 250
fig_id = 0
fig, axes = plt.subplots(1, 3, figsize=(12,6), sharex=True)
np.random.seed(2502)

# BS
t, price = sim_jump_diffusion(X0, T, Ndt, mu, sigma, Nsims)
# Plot the sample paths
axes[0].plot(t, price[:,1:10], linewidth=0.3)
axes[0].plot(t, np.quantile(price, [0.1, 0.5, 0.9], axis=1).transpose(),
            linewidth=1.5, color='black')
axes[0].set_title("BS: " + r"mu = " + str(mu) + r", sigma = " + str(sigma))
axes[0].set_xlabel('Time')
axes[0].set_ylabel('Value')
axes[0].set_ylim([0, ylim])

# Merton
t, price = sim_jump_diffusion(X0, T, Ndt, mu, sigma, Nsims, "Merton", lam, m = m[fig_id], delta = delta[fig_id])
# Plot the sample paths
axes[1].plot(t, price[:,1:10], linewidth=0.3)
axes[1].plot(t, np.quantile(price, [0.1, 0.5, 0.9], axis=1).transpose(),
            linewidth=1.5, color='black')
axes[1].set_title("Merton: " + r"m = " + str(m[fig_id]) + r", delta = " + str(delta[fig_id]))
axes[1].set_xlabel('Time')
axes[1].set_ylabel('Value')
axes[1].set_ylim([0, ylim])

# Kou
t, price = sim_jump_diffusion(X0, T, Ndt, mu, sigma, Nsims, "Kou", lam, p = p[fig_id], eta = eta[fig_id])
# Plot the sample paths
axes[2].plot(t, price[:,1:10], linewidth=0.3)
axes[2].plot(t, np.quantile(price, [0.1, 0.5, 0.9], axis=1).transpose(),
            linewidth=1.5, color='black')
axes[2].set_title("Kou: " + r"p = " + str(p[fig_id]) + r", eta = " + str(eta[fig_id]))
axes[2].set_xlabel('Time')
axes[2].set_ylabel('Value')
axes[2].set_ylim([0, ylim])

plt.show()

## Figures - Large Parameters
ylim = 500
fig_id = 1
fig, axes = plt.subplots(1, 3, figsize=(12,6), sharex=True)
np.random.seed(2502)

# BS
t, price = sim_jump_diffusion(X0, T, Ndt, mu, sigma, Nsims)
# Plot the sample paths
axes[0].plot(t, price[:,1:10], linewidth=0.3)
axes[0].plot(t, np.quantile(price, [0.1, 0.5, 0.9], axis=1).transpose(),
            linewidth=1.5, color='black')
axes[0].set_title("BS: " + r"mu = " + str(mu) + r", sigma = " + str(sigma))
axes[0].set_xlabel('Time')
axes[0].set_ylabel('Value')
axes[0].set_ylim([0, ylim])

# Merton
t, price = sim_jump_diffusion(X0, T, Ndt, mu, sigma, Nsims, "Merton", lam, m = m[fig_id], delta = delta[fig_id])
# Plot the sample paths
axes[1].plot(t, price[:,1:10], linewidth=0.3)
axes[1].plot(t, np.quantile(price, [0.1, 0.5, 0.9], axis=1).transpose(),
            linewidth=1.5, color='black')
axes[1].set_title("Merton: " + r"m = " + str(m[fig_id]) + r", delta = " + str(delta[fig_id]))
axes[1].set_xlabel('Time')
axes[1].set_ylabel('Value')
axes[1].set_ylim([0, ylim])

# Kou
t, price = sim_jump_diffusion(X0, T, Ndt, mu, sigma, Nsims, "Kou", lam, p = p[fig_id], eta = eta[fig_id])
# Plot the sample paths
axes[2].plot(t, price[:,1:10], linewidth=0.3)
axes[2].plot(t, np.quantile(price, [0.1, 0.5, 0.9], axis=1).transpose(),
            linewidth=1.5, color='black')
axes[2].set_title("Kou: " + r"p = " + str(p[fig_id]) + r", eta = " + str(eta[fig_id]))
axes[2].set_xlabel('Time')
axes[2].set_ylabel('Value')
axes[2].set_ylim([0, ylim])

plt.show()

# %% [markdown]
# Section 6: Option Pricing

# %%
## Helper functions
# Black-Scholes
def call_BS(St, k, r, sigma, T, t = 0):
    dpos = (np.log(St/k) + (r + sigma**2/2)*(T - t))/(sigma * np.sqrt(T - t))
    dneg = (np.log(St/k) + (r - sigma**2/2)*(T - t))/(sigma * np.sqrt(T - t))
    return St * stats.norm.cdf(dpos) - k * np.exp(-r * (T - t)) * stats.norm.cdf(dneg)

# Merton
def call_Merton(lam, m, delta, St, k, r, sigma, T, t = 0):
    val = np.zeros(len(St))
    lam_bar = lam * np.exp(m + delta**2/2)
    delta_T = T - t
    # for i in range(100):
    for j in range(len(St)):
        i = 0
        diff = 1
        while diff > 0.00001:
            sigma_i = np.sqrt(sigma**2 + (i * delta**2)/delta_T)
            r_i = r - lam * (np.exp(m + delta**2/2) - 1) + i*(m + delta**2/2)/delta_T
            diff = (lam_bar * delta_T)**i/np.math.factorial(i) * call_BS(St[j], k, r_i, sigma_i, T, t)
            val[j] += diff
            i += 1
    return np.exp(-lam_bar * delta_T) * val

# %% [markdown]
# Plots - Option Pricing

# %%
## Figures
# Parameters
St = np.arange(1, 101) #50
k = 50 #np.arange(20, 80) + 1
r = 0.05
T = 0.25
Ndt = 1000
sigma_BS = 0.5
# Merton
lam = 4
m = -0.05
delta = 0.2
sigma_Merton = np.sqrt(sigma_BS**2 - lam * (delta**2 + m**2))
print(sigma_BS**2 - lam * (delta**2 + m**2))

# Call prices - Plots
# Figure params
lw = 1

# Setup
np.random.seed(2502)
fig, axes = plt.subplots(1, 2, figsize=(12,6), sharex=True)

# Constant diffusion
price1 = np.transpose(np.array([call_BS(St, k, r, sigma_BS, T), call_Merton(lam, m, delta, St, k, r, sigma_BS, T)]))
# Plot the call price
axes[0].plot(St, price1, linewidth=lw, label = ["BS", "Merton"])
axes[0].vlines(x=k, ymin=0, ymax=50, colors = 'gray', linestyles = 'dotted')
axes[0].set_title("Constant Diffusion: " + r"sigma = " + str(sigma_BS))
axes[0].set_xlabel('Asset Price (St)')
axes[0].set_ylabel('Call Price')
axes[0].legend()

# Adjusted diffusion
price2 = np.transpose(np.array([call_BS(St, k, r, sigma_BS, T), call_Merton(lam, m, delta, St, k, r, sigma_Merton, T)]))
# Plot the call price
axes[1].plot(St, price2, linewidth=lw, label = ["BS", "Merton"])
axes[1].vlines(x=k, ymin=0, ymax=50, colors = 'gray', linestyles = 'dotted')
axes[1].set_title("Adjusted Diffusion: " + r"sigmaMerton = " + str(round(sigma_Merton, 4)))
axes[1].set_xlabel('Asset Price (St)')
axes[1].set_ylabel('Call Price')
axes[1].legend()

plt.show()

# %% [markdown]
# Delta (Greeks)

# %%
# Delta-Greek Approximation
def greek_delta(prices, end, start = 0):
    dt = (end - start)/(len(prices) - 1)
    dprices = np.zeros(len(prices))
    dprices[1:len(prices)] = prices[1:len(prices)] - prices[0:(len(prices) - 1)]
    dprices[0] = dprices[1]

    return dprices / dt

# %% [markdown]
# Plots

# %%
# Setup
fig, axes = plt.subplots(1, 2, figsize=(12,6), sharex=True)

# Constant diffusion
delta_greek1 = np.transpose(np.array([greek_delta(price1[:, 0], 100, 1), greek_delta(price1[:, 1], 100, 1)]))
# Plot the delta (greeks) approximation
axes[0].plot(St, delta_greek1, linewidth=lw, label = ["BS", "Merton"])
axes[0].vlines(x=k, ymin=0, ymax=1, colors = 'gray', linestyles = 'dotted')
axes[0].set_title("Constant Diffusion: " + r"sigma = " + str(sigma_BS))
axes[0].set_xlabel('Asset Price (St)')
axes[0].set_ylabel('Delta')
axes[0].legend()

# Adjusted diffusion
delta_greek2 = np.transpose(np.array([greek_delta(price2[:, 0], 100, 1), greek_delta(price2[:, 1], 100, 1)]))
# Plot the delta (greeks) approximation
axes[1].plot(St, delta_greek2, linewidth=lw, label = ["BS", "Merton"])
axes[1].vlines(x=k, ymin=0, ymax=1, colors = 'gray', linestyles = 'dotted')
axes[1].set_title("Adjusted Diffusion: " + r"sigmaMerton = " + str(round(sigma_Merton, 4)))
axes[1].set_xlabel('Asset Price (St)')
axes[1].set_ylabel('Delta')
axes[1].legend()

plt.show()
